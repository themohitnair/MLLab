# %% [markdown]
# #### Write a notebook to demonstrate the working of the decision tree based ID3 algorithm. Use an appropriate data set for building the decision tree and apply this knowledge to classify a new sample. Interpret the results. Write the inference/analysis of each output.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
data = {
    'Outlook': ['Sunny', 'Sunny', 'Overcast', 'Rain', 'Rain', 'Rain', 'Overcast', 'Sunny', 'Sunny', 'Rain', 'Sunny', 'Overcast', 'Overcast', 'Rain'],
    'Temperature': ['Hot', 'Hot', 'Hot', 'Mild', 'Cool', 'Cool', 'Cool', 'Mild', 'Cool', 'Mild', 'Mild', 'Mild', 'Hot', 'Mild'],
    'Humidity': ['High', 'High', 'High', 'High', 'High', 'Low', 'Low', 'High', 'Low', 'Low', 'Low', 'High', 'Low', 'High'],
    'Wind': ['Weak', 'Strong', 'Weak', 'Weak', 'Weak', 'Weak', 'Strong', 'Weak', 'Weak', 'Weak', 'Strong', 'Strong', 'Weak', 'Strong'],
    'PlayTennis': ['No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No']
}

# %%
df = pd.DataFrame(data)


X = df.drop("PlayTennis", axis=1)
y = df["PlayTennis"]

# %%
X_encoded = pd.get_dummies(X)

clf = DecisionTreeClassifier(criterion="entropy")


clf.fit(X_encoded, y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
fig, ax = plt.subplots(figsize=(12, 12))


tree.plot_tree(
    clf, feature_names=X_encoded.columns, class_names=clf.classes_, filled=True, ax=ax
)
# Out:
# [Text(0.7, 0.9166666666666666, 'Outlook_Overcast <= 0.5\nentropy = 0.94\nsamples = 14\nvalue = [5, 9]\nclass = Yes'),
#  Text(0.6, 0.75, 'Temperature_Hot <= 0.5\nentropy = 1.0\nsamples = 10\nvalue = [5, 5]\nclass = No'),
#  Text(0.6499999999999999, 0.8333333333333333, 'True  '),
#  Text(0.5, 0.5833333333333334, 'Humidity_Low <= 0.5\nentropy = 0.954\nsamples = 8\nvalue = [3, 5]\nclass = Yes'),
#  Text(0.3, 0.4166666666666667, 'Outlook_Sunny <= 0.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = No'),
#  Text(0.2, 0.25, 'Wind_Weak <= 0.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Yes'),
#  Text(0.1, 0.08333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No'),
#  Text(0.3, 0.08333333333333333, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes'),
#  Text(0.4, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No'),
#  Text(0.7, 0.4166666666666667, 'Temperature_Cool <= 0.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = Yes'),
# ...

# %%
plt.savefig("decision_tree.jpeg", format="jpeg", bbox_inches="tight")


plt.show()

print("Decision tree saved as 'decision_tree.jpeg'.")
# Out:
# Decision tree saved as 'decision_tree.jpeg'.
