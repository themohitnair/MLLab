# %%
import pandas as pd 
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt 
from sklearn.metrics import ConfusionMatrixDisplay, matthews_corrcoef, precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, auc, roc_curve
from sklearn.model_selection import train_test_split

# %%
data = load_breast_cancer()
X = data.data
y = data.target

# %%
print(data.target_names)
# Out:
# ['malignant' 'benign']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
cm = confusion_matrix(y_pred=y_pred, y_true=y_test)
print(cm)
# Out:
# [[51  3]
#  [ 2 87]]

# %%
conf = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=data.target_names)
conf.plot(cmap=plt.cm.Blues)
plt.show()

# %%
TP = cm[0][0]
FN = cm[0][1]
FP = cm[1][0] 
TN = cm[1][1]

print(f"True Positives: {TP}\nFalse Negatives: {FN}\nFalse Positives: {FP}\nTrue Negatives: {TN}")
# Out:
# True Positives: 51
# False Negatives: 3
# False Positives: 2
# True Negatives: 87

# %%
accuracy = accuracy_score(y_pred=y_pred, y_true=y_test)
calc_accuracy = (TP + TN) / (TP + TN + FP + FN)

print(f"Accuracy: {accuracy}\nCalculated Accuracy: {calc_accuracy}")
# Out:
# Accuracy: 0.965034965034965
# Calculated Accuracy: 0.965034965034965

# %%
precision = precision_score(y_pred=y_pred, y_true=y_test)
calc_precision = TP / (TP + FP)

print(f"Precision: {precision}\nCalculated Precision: {calc_precision}")
# Out:
# Precision: 0.9666666666666667
# Calculated Precision: 0.9622641509433962

# %%
recall = recall_score(y_pred=y_pred, y_true=y_test)
calc_recall = TP / (TP + FN)

print(f"Recall: {recall}\nCalculated Recall: {calc_recall}")
# Out:
# Recall: 0.9775280898876404
# Calculated Recall: 0.9444444444444444

# %%
f1 = f1_score(y_pred=y_pred, y_true=y_test)
calc_f1 = (2 * precision * recall) / (precision + recall)

print(f"F1 Score: {f1}\nCalculated F1 Score: {calc_f1}")
# Out:
# F1 Score: 0.9720670391061452
# Calculated F1 Score: 0.9720670391061451

# %%
mcc = matthews_corrcoef(y_pred=y_pred, y_true=y_test)
calc_mcc = (TP * TN - FP * FN) / (((FP + TP) * (TP + FN) * (FP + TN) * (FN + TN)) ** 0.5)

print(f"Matthew's Correlation Coefficient: {mcc}\nCalculated Matthew's Correlation Coefficient: {calc_mcc}")
# Out:
# Matthew's Correlation Coefficient: 0.925445136208044
# Calculated Matthew's Correlation Coefficient: 0.925445136208044

# %%
calc_specificity = TN / (TN + FP) 
calc_npv = TN / (TN + FN)

print(f"Specificity: {calc_specificity}\nNPV: {calc_npv}")
# Out:
# Specificity: 0.9775280898876404
# NPV: 0.9666666666666667

# %%
y_pred_proba = model.predict_proba(X_test)[:, 1]

np.random.seed(42)
y_random_proba = np.random.random(len(y_test))

# %%
fpr_model, tpr_model, _ = roc_curve(y_test, y_pred_proba)
fpr_random, tpr_random, _ = roc_curve(y_test, y_random_proba)

# %%
auc_model = roc_auc_score(y_test, y_pred_proba)
print(f"Model AUC Score: {auc}")
# Out:
# Model AUC Score: <function auc at 0x744c059f7d80>

# %%
plt.figure(figsize=(10, 8))
plt.plot(fpr_random, tpr_random, color="darkorange", lw=2, label="Random ROC Curve")
plt.plot(fpr_model, tpr_model, color="red", lw=2, label="Model ROC Curve")
plt.plot([0, 1], [0, 1], color='navy', lw=2, label="Baseline")

plt.legend(loc="lower right")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Random Classifier vs Random Forest Classifier (Breast Cancer Detection)")
# Out:
# Text(0.5, 1.0, 'Random Classifier vs Random Forest Classifier (Breast Cancer Detection)')
